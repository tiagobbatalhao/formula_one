# %% [markdown]
# # Load historical sessions

# %%
import os
from dotenv import load_dotenv
import fastf1
import pandas as pd
from datetime import datetime
import sys
sys.path.append('..')
import utils
load_dotenv("../../.envrc")
# Out:
# True

# %% [markdown]
# ## Load from API

# %%
def get_year_schedule(year):
    schedule = fastf1.get_event_schedule(year)
    return schedule

# %%
schedules = [
    (year, get_year_schedule(year))
    for year in range(1950, 2023)
]
# Out:
# api         WARNING
#
# NO CACHE! Api caching has not been enabled!
# 	It is highly recommended to enable this feature for much faster data loading!
# 	Use `fastf1.Cache.enable_cache('path/to/cache/')`

# %%
columns = list(schedules[-1][1].columns)
import collections
collections.Counter([list(x[1].columns)==columns for x in schedules])
# Out:
# Counter({True: 73})

# %%
df_schedules = pd.DataFrame(pd.concat([
    val.assign(Year=key) for key, val in schedules
]))

# %%
df_schedules
# Out:
#     RoundNumber        Country      Location  \
# 0             1             UK   Silverstone
# 1             2         Monaco   Monte-Carlo
# 2             3            USA  Indianapolis
# 3             4    Switzerland          Bern
# 4             5        Belgium           Spa
# ..          ...            ...           ...
# 19           18          Japan        Suzuka
# 20           19  United States        Austin
# 21           20         Mexico   Mexico City
# 22           21         Brazil     São Paulo
# 23           22      Abu Dhabi    Yas Island
#
#                                     OfficialEventName           EventDate  \
# 0                                                     1950-05-13 00:00:00
# 1                                                     1950-05-21 00:00:00
# 2                                                     1950-05-30 00:00:00
# 3                                                     1950-06-04 00:00:00
# 4                                                     1950-06-18 00:00:00
# ..                                                ...                 ...
# 19           FORMULA 1 HONDA JAPANESE GRAND PRIX 2022 2022-10-09 16:00:00
# 20     FORMULA 1 ARAMCO UNITED STATES GRAND PRIX 2022 2022-10-23 16:00:00
# 21  FORMULA 1 GRAN PREMIO DE LA CIUDAD DE MÉXICO 2022 2022-10-30 16:00:00
# 22  FORMULA 1 HEINEKEN GRANDE PRÊMIO DE SÃO PAULO ... 2022-11-13 17:00:00
# 23  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ... 2022-11-20 19:00:00
#
#                    EventName   EventFormat    Session1        Session1Date  \
# 0         British Grand Prix  conventional  Practice 1 1950-05-11 00:00:00
# 1          Monaco Grand Prix  conventional  Practice 1 1950-05-19 00:00:00
# 2           Indianapolis 500  conventional  Practice 1 1950-05-28 00:00:00
# 3           Swiss Grand Prix  conventional  Practice 1 1950-06-02 00:00:00
# 4         Belgian Grand Prix  conventional  Practice 1 1950-06-16 00:00:00
# ..                       ...           ...         ...                 ...
# 19       Japanese Grand Prix  conventional  Practice 1 2022-10-07 12:00:00
# 20  United States Grand Prix  conventional  Practice 1 2022-10-21 14:00:00
# 21    Mexico City Grand Prix  conventional  Practice 1 2022-10-28 13:00:00
# 22      São Paulo Grand Prix        sprint  Practice 1 2022-11-11 12:30:00
# 23      Abu Dhabi Grand Prix  conventional  Practice 1 2022-11-18 14:00:00
#
#       Session2        Session2Date    Session3        Session3Date  \
# 0   Practice 2 1950-05-11 00:00:00  Practice 3 1950-05-12 00:00:00
# 1   Practice 2 1950-05-19 00:00:00  Practice 3 1950-05-20 00:00:00
# 2   Practice 2 1950-05-28 00:00:00  Practice 3 1950-05-29 00:00:00
# 3   Practice 2 1950-06-02 00:00:00  Practice 3 1950-06-03 00:00:00
# 4   Practice 2 1950-06-16 00:00:00  Practice 3 1950-06-17 00:00:00
# ..         ...                 ...         ...                 ...
# 19  Practice 2 2022-10-07 15:00:00  Practice 3 2022-10-08 12:00:00
# 20  Practice 2 2022-10-21 17:00:00  Practice 3 2022-10-22 14:00:00
# 21  Practice 2 2022-10-28 16:00:00  Practice 3 2022-10-29 12:00:00
# 22  Qualifying 2022-11-11 16:00:00  Practice 2 2022-11-12 12:30:00
# 23  Practice 2 2022-11-18 17:00:00  Practice 3 2022-11-19 15:00:00
#
#       Session4        Session4Date Session5        Session5Date  F1ApiSupport  \
# 0   Qualifying 1950-05-12 00:00:00     Race 1950-05-13 00:00:00         False
# 1   Qualifying 1950-05-20 00:00:00     Race 1950-05-21 00:00:00         False
# 2   Qualifying 1950-05-29 00:00:00     Race 1950-05-30 00:00:00         False
# 3   Qualifying 1950-06-03 00:00:00     Race 1950-06-04 00:00:00         False
# 4   Qualifying 1950-06-17 00:00:00     Race 1950-06-18 00:00:00         False
# ..         ...                 ...      ...                 ...           ...
# 19  Qualifying 2022-10-08 15:00:00     Race 2022-10-09 14:00:00          True
# 20  Qualifying 2022-10-22 17:00:00     Race 2022-10-23 14:00:00          True
# 21  Qualifying 2022-10-29 15:00:00     Race 2022-10-30 14:00:00          True
# 22      Sprint 2022-11-12 16:30:00     Race 2022-11-13 15:00:00          True
# 23  Qualifying 2022-11-19 18:00:00     Race 2022-11-20 17:00:00          True
#
#     Year
# 0   1950
# 1   1950
# 2   1950
# 3   1950
# 4   1950
# ..   ...
# 19  2022
# 20  2022
# 21  2022
# 22  2022
# 23  2022
#
# [1084 rows x 19 columns]

# %% [markdown]
# ## Exporting schedules to BigQuery

# %%
bigquery_params = {
    "project": os.environ["BIGQUERY_PROJECT"],
    "dataset": os.environ["BIGQUERY_DATASET"],
    "credentials_path": os.environ["GOOGLE_APPLICATION_CREDENTIALS"],
    "table": "src_schedule",
    "schema": [
        ("Year", "INTEGER", "NULLABLE"),
        ("RoundNumber", "INTEGER", "NULLABLE"),
        ("Country", "STRING", "NULLABLE"),
        ("Location", "STRING", "NULLABLE"),
        ("OfficialEventName", "STRING", "NULLABLE"),
        ("EventDate", "TIMESTAMP", "NULLABLE"),
        ("EventName", "STRING", "NULLABLE"),
        ("EventFormat", "STRING", "NULLABLE"),
        ("Session1", "STRING", "NULLABLE"),
        ("Session1Date", "TIMESTAMP", "NULLABLE"),
        ("Session2", "STRING", "NULLABLE"),
        ("Session2Date", "TIMESTAMP", "NULLABLE"),
        ("Session3", "STRING", "NULLABLE"),
        ("Session3Date", "TIMESTAMP", "NULLABLE"),
        ("Session4", "STRING", "NULLABLE"),
        ("Session4Date", "TIMESTAMP", "NULLABLE"),
        ("Session5", "STRING", "NULLABLE"),
        ("Session5Date", "TIMESTAMP", "NULLABLE"),
        ("F1ApiSupport", "BOOLEAN", "NULLABLE"),
        ("uploaded_at", "TIMESTAMP", "NULLABLE"),
    ],
}

# %%
bq = utils.BigQuery(
    project=bigquery_params["project"],
    dataset=bigquery_params["dataset"],
    credentials_path=bigquery_params["credentials_path"],
)
bq.write_data(
    df_schedules.assign(uploaded_at=datetime.utcnow()),
    table_name=bigquery_params["table"],
    schema=bigquery_params["schema"],
)
# Out:
# 2023-01-28 16:35:09.926 | INFO     | utils:write_data:54 - Writing 1084 rows to table tiagobbatalhao-personal:formula_one.src_schedule
# LoadJob<project=tiagobbatalhao-personal, location=southamerica-east1, id=387dbc0a-f5a0-41b2-9151-1274f762abaa>
