# %%
import pandas as pd
import numpy as np
import fastf1
from pathlib import Path
import os
from datetime import datetime
from dotenv import load_dotenv
from loguru import logger
import argparse
import sys
from pathlib import Path
sys.path.append(str(Path('.').absolute().parent))
import utils

path_cache = Path('.').absolute().parent.parent / ".cache"
fastf1.Cache.enable_cache(str(path_cache))
path_dotenv = Path('.').parent.parent / ".envrc"
load_dotenv(str(path_dotenv))
# Out:
# False

# %%
path_cache
# Out:
# PosixPath('/Users/tiagobbatalhao/Documents/personal_repos/formula_one/.cache')

# %%
session = fastf1.get_session(2023, 'Australian Grand Prix', 'FP1')

# %%
session.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Practice 1 [v2.3.0]
# api            INFO 	No cached data found for driver_info. Loading data...
# api            INFO 	Fetching driver list...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_app_data. Loading data...
# api            INFO 	Fetching timing app data...
# api            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# api            INFO 	No cached data found for session_status_data. Loading data...
# api            INFO 	Fetching session status data...
# api            INFO 	Data has been written to cache!
# ...

# %%
laps = session.laps.pick_driver(44)
for lp in laps.iterlaps():
    print(lp)
# Out:
# (60, Time                      0 days 00:19:27.983000
# DriverNumber                                  44
# LapTime                   0 days 00:01:57.398000
# LapNumber                                      1
# PitOutTime                0 days 00:17:33.550000
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:58.657000
# Sector2Time               0 days 00:00:19.713000
# Sector3Time               0 days 00:00:39.028000
# Sector1SessionTime        0 days 00:18:29.393000
# Sector2SessionTime        0 days 00:18:49.127000
# Sector3SessionTime        0 days 00:19:28.080000
# SpeedI1                                    253.0
# SpeedI2                                    299.0
# SpeedFL                                    295.0
# SpeedST                                    196.0
# IsPersonalBest                             False
# Compound                                  MEDIUM
# TyreLife                                     1.0
# ...

# %%
laps = list(session.laps.pick_driver(44).iterlaps())

# %%
laps[0][1]['LapNumber']
# Out:
# 1

# %%
laps[2][1].get_pos_data()
# Out:
# /Users/tiagobbatalhao/.virtualenvs/formula_one/lib/python3.9/site-packages/fastf1/core.py:378: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_slice.loc[:, 'Time'] = data_slice['SessionTime'] - start_time
#                        Date   Status     X     Y   Z Source  \
# 0   2023-03-31 01:35:51.158  OnTrack -1256 -1276  84    pos
# 1   2023-03-31 01:35:51.418  OnTrack -1414 -1126  83    pos
# 2   2023-03-31 01:35:51.638  OnTrack -1548  -999  82    pos
# 3   2023-03-31 01:35:51.798  OnTrack -1646  -906  82    pos
# 4   2023-03-31 01:35:52.018  OnTrack -1781  -777  80    pos
# ..                      ...      ...   ...   ...  ..    ...
# 367 2023-03-31 01:37:25.918  OnTrack  -625 -1876  88    pos
# 368 2023-03-31 01:37:26.118  OnTrack  -744 -1763  88    pos
# ...
